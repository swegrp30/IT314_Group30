# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060396
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062553
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063632
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062014
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060936
# ...          ...         ...         ...         ...         ...         ...
# 9487  2023-11-02  347.239990  348.829987  344.769989  348.320007  348.320007
# 9488  2023-11-03  349.630005  354.390015  347.329987  352.799988  352.799988
# 9489  2023-11-06  353.450012  357.540009  353.350006  356.529999  356.529999
# 9490  2023-11-07  359.399994  362.459991  357.630005  360.529999  360.529999
# 9491  2023-11-08  361.679993  363.869995  360.549988  363.200012  363.200012
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9487    24348100
# 9488    23624000
# 9489    23828300
# 9490    25833900
# 9491    26747900
#
# [9492 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9487    2023-11-02
# 9488    2023-11-03
# 9489    2023-11-06
# 9490    2023-11-07
# 9491    2023-11-08
# Name: Date, Length: 9492, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('2023-11-08')
datetime_object
# Out:
# datetime.datetime(2023, 11, 8, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
# Out:
# <ipython-input-10-82fc7f804c29>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)

# %%
df['Date']
# Out:
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9487   2023-11-02
# 9488   2023-11-03
# 9489   2023-11-06
# 9490   2023-11-07
# 9491   2023-11-08
# Name: Date, Length: 9492, dtype: datetime64[ns]

# %%
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-11-02  348.320007
# 2023-11-03  352.799988
# 2023-11-06  356.529999
# 2023-11-07  360.529999
# 2023-11-08  363.200012
#
# [9492 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 90ms/step - loss: 84723.5391 - mean_absolute_error: 289.3338 - val_loss: 92384.6875 - val_mean_absolute_error: 303.8614
# Epoch 2/100
# 7/7 [==============================] - 0s 6ms/step - loss: 84449.5938 - mean_absolute_error: 288.8590 - val_loss: 92157.3203 - val_mean_absolute_error: 303.4870
# Epoch 3/100
# 7/7 [==============================] - 0s 5ms/step - loss: 84246.6562 - mean_absolute_error: 288.5061 - val_loss: 91915.4062 - val_mean_absolute_error: 303.0881
# Epoch 4/100
# 7/7 [==============================] - 0s 6ms/step - loss: 83975.9531 - mean_absolute_error: 288.0380 - val_loss: 91559.8516 - val_mean_absolute_error: 302.5011
# Epoch 5/100
# 7/7 [==============================] - 0s 5ms/step - loss: 83604.2969 - mean_absolute_error: 287.3957 - val_loss: 91110.4688 - val_mean_absolute_error: 301.7574
# Epoch 6/100
# 7/7 [==============================] - 0s 5ms/step - loss: 83095.9141 - mean_absolute_error: 286.5013 - val_loss: 90415.9922 - val_mean_absolute_error: 300.6044
# Epoch 7/100
# 7/7 [==============================] - 0s 5ms/step - loss: 82391.9766 - mean_absolute_error: 285.2726 - val_loss: 89627.6562 - val_mean_absolute_error: 299.2903
# Epoch 8/100
# 7/7 [==============================] - 0s 5ms/step - loss: 81603.3672 - mean_absolute_error: 283.8907 - val_loss: 88673.1875 - val_mean_absolute_error: 297.6914
# Epoch 9/100
# 7/7 [==============================] - 0s 5ms/step - loss: 80494.2031 - mean_absolute_error: 281.9255 - val_loss: 87191.1562 - val_mean_absolute_error: 295.1917
# Epoch 10/100
# 7/7 [==============================] - 0s 5ms/step - loss: 78956.9609 - mean_absolute_error: 279.1862 - val_loss: 85366.9062 - val_mean_absolute_error: 292.0855
# Epoch 11/100
# 7/7 [==============================] - 0s 5ms/step - loss: 77176.9375 - mean_absolute_error: 275.9740 - val_loss: 83320.5938 - val_mean_absolute_error: 288.5612
# Epoch 12/100
# 7/7 [==============================] - 0s 9ms/step - loss: 74927.4297 - mean_absolute_error: 271.8622 - val_loss: 80383.9531 - val_mean_absolute_error: 283.4272
# Epoch 13/100
# 7/7 [==============================] - 0s 5ms/step - loss: 71956.8203 - mean_absolute_error: 266.3474 - val_loss: 76870.8125 - val_mean_absolute_error: 277.1602
# Epoch 14/100
# 7/7 [==============================] - 0s 6ms/step - loss: 68285.0234 - mean_absolute_error: 259.3611 - val_loss: 72458.3750 - val_mean_absolute_error: 269.0824
# Epoch 15/100
# 7/7 [==============================] - 0s 6ms/step - loss: 64026.2031 - mean_absolute_error: 251.0250 - val_loss: 67894.8750 - val_mean_absolute_error: 260.4647
# Epoch 16/100
# 7/7 [==============================] - 0s 5ms/step - loss: 59489.5469 - mean_absolute_error: 241.8196 - val_loss: 62522.8203 - val_mean_absolute_error: 249.9396
# Epoch 17/100
# 7/7 [==============================] - 0s 5ms/step - loss: 54133.3281 - mean_absolute_error: 230.4953 - val_loss: 56292.2500 - val_mean_absolute_error: 237.1482
# Epoch 18/100
# 7/7 [==============================] - 0s 5ms/step - loss: 48155.5273 - mean_absolute_error: 217.1334 - val_loss: 49948.9336 - val_mean_absolute_error: 223.3741
# Epoch 19/100
# 7/7 [==============================] - 0s 6ms/step - loss: 42236.1406 - mean_absolute_error: 202.9521 - val_loss: 43458.6836 - val_mean_absolute_error: 208.3402
# Epoch 20/100
# 7/7 [==============================] - 0s 6ms/step - loss: 35988.6133 - mean_absolute_error: 186.9880 - val_loss: 36227.2695 - val_mean_absolute_error: 190.1948
# Epoch 21/100
# 7/7 [==============================] - 0s 5ms/step - loss: 29234.9512 - mean_absolute_error: 167.8266 - val_loss: 29198.0020 - val_mean_absolute_error: 170.7191
# Epoch 22/100
# 7/7 [==============================] - 0s 6ms/step - loss: 23079.1191 - mean_absolute_error: 148.4751 - val_loss: 22732.1152 - val_mean_absolute_error: 150.5954
# Epoch 23/100
# 7/7 [==============================] - 0s 6ms/step - loss: 17391.1484 - mean_absolute_error: 127.9297 - val_loss: 17005.9629 - val_mean_absolute_error: 130.2037
# Epoch 24/100
# 7/7 [==============================] - 0s 6ms/step - loss: 12644.0146 - mean_absolute_error: 107.6098 - val_loss: 12130.1299 - val_mean_absolute_error: 109.8961
# Epoch 25/100
# 7/7 [==============================] - 0s 6ms/step - loss: 8692.8027 - mean_absolute_error: 87.5578 - val_loss: 8215.4727 - val_mean_absolute_error: 90.3466
# Epoch 26/100
# 7/7 [==============================] - 0s 5ms/step - loss: 5756.3936 - mean_absolute_error: 68.4008 - val_loss: 5242.5874 - val_mean_absolute_error: 72.0390
# Epoch 27/100
# 7/7 [==============================] - 0s 6ms/step - loss: 3609.8440 - mean_absolute_error: 51.2176 - val_loss: 3197.9858 - val_mean_absolute_error: 56.0805
# Epoch 28/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2322.9172 - mean_absolute_error: 38.6977 - val_loss: 1841.1364 - val_mean_absolute_error: 42.2865
# Epoch 29/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1540.0540 - mean_absolute_error: 32.0554 - val_loss: 962.2328 - val_mean_absolute_error: 30.1530
# Epoch 30/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1162.9127 - mean_absolute_error: 28.6602 - val_loss: 501.1275 - val_mean_absolute_error: 21.1709
# Epoch 31/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1023.9500 - mean_absolute_error: 27.0580 - val_loss: 312.8361 - val_mean_absolute_error: 16.1322
# Epoch 32/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1003.0773 - mean_absolute_error: 26.7435 - val_loss: 209.7528 - val_mean_absolute_error: 12.7782
# Epoch 33/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1023.0680 - mean_absolute_error: 26.9978 - val_loss: 177.7292 - val_mean_absolute_error: 11.5343
# Epoch 34/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1021.3609 - mean_absolute_error: 26.9790 - val_loss: 190.6005 - val_mean_absolute_error: 12.0513
# Epoch 35/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1016.0745 - mean_absolute_error: 26.9470 - val_loss: 220.1503 - val_mean_absolute_error: 13.1536
# Epoch 36/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1010.9290 - mean_absolute_error: 26.8861 - val_loss: 239.4671 - val_mean_absolute_error: 13.8221
# Epoch 37/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1010.4943 - mean_absolute_error: 26.8753 - val_loss: 251.8765 - val_mean_absolute_error: 14.2334
# Epoch 38/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1009.9355 - mean_absolute_error: 26.8743 - val_loss: 266.6021 - val_mean_absolute_error: 14.7051
# Epoch 39/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1009.3920 - mean_absolute_error: 26.8517 - val_loss: 264.2877 - val_mean_absolute_error: 14.6323
# Epoch 40/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1008.2088 - mean_absolute_error: 26.8317 - val_loss: 276.7900 - val_mean_absolute_error: 15.0227
# Epoch 41/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1007.1697 - mean_absolute_error: 26.8182 - val_loss: 285.3914 - val_mean_absolute_error: 15.2872
# Epoch 42/100
# 7/7 [==============================] - 0s 5ms/step - loss: 997.5127 - mean_absolute_error: 26.6956 - val_loss: 337.3635 - val_mean_absolute_error: 16.8953
# Epoch 43/100
# 7/7 [==============================] - 0s 5ms/step - loss: 982.2488 - mean_absolute_error: 26.5076 - val_loss: 321.6848 - val_mean_absolute_error: 16.4316
# Epoch 44/100
# 7/7 [==============================] - 0s 6ms/step - loss: 975.3452 - mean_absolute_error: 26.4148 - val_loss: 281.5953 - val_mean_absolute_error: 15.1954
# Epoch 45/100
# 7/7 [==============================] - 0s 6ms/step - loss: 968.7156 - mean_absolute_error: 26.3063 - val_loss: 294.6956 - val_mean_absolute_error: 15.6084
# Epoch 46/100
# 7/7 [==============================] - 0s 6ms/step - loss: 960.5685 - mean_absolute_error: 26.2195 - val_loss: 253.6292 - val_mean_absolute_error: 14.3349
# Epoch 47/100
# 7/7 [==============================] - 0s 6ms/step - loss: 948.2458 - mean_absolute_error: 26.0267 - val_loss: 219.0490 - val_mean_absolute_error: 13.1649
# Epoch 48/100
# 7/7 [==============================] - 0s 6ms/step - loss: 943.9213 - mean_absolute_error: 25.9790 - val_loss: 261.5866 - val_mean_absolute_error: 14.6058
# Epoch 49/100
# 7/7 [==============================] - 0s 5ms/step - loss: 930.6705 - mean_absolute_error: 25.7826 - val_loss: 188.8260 - val_mean_absolute_error: 12.0553
# Epoch 50/100
# 7/7 [==============================] - 0s 6ms/step - loss: 928.9309 - mean_absolute_error: 25.8613 - val_loss: 268.7400 - val_mean_absolute_error: 14.8518
# Epoch 51/100
# 7/7 [==============================] - 0s 5ms/step - loss: 893.0127 - mean_absolute_error: 25.2018 - val_loss: 227.8623 - val_mean_absolute_error: 13.5306
# Epoch 52/100
# 7/7 [==============================] - 0s 7ms/step - loss: 860.3180 - mean_absolute_error: 24.7244 - val_loss: 339.6011 - val_mean_absolute_error: 17.0999
# Epoch 53/100
# 7/7 [==============================] - 0s 5ms/step - loss: 834.6547 - mean_absolute_error: 24.3985 - val_loss: 186.2356 - val_mean_absolute_error: 12.0296
# Epoch 54/100
# 7/7 [==============================] - 0s 5ms/step - loss: 816.9685 - mean_absolute_error: 24.1979 - val_loss: 273.1291 - val_mean_absolute_error: 15.0778
# Epoch 55/100
# 7/7 [==============================] - 0s 6ms/step - loss: 785.8554 - mean_absolute_error: 23.6424 - val_loss: 175.2646 - val_mean_absolute_error: 11.6334
# Epoch 56/100
# 7/7 [==============================] - 0s 5ms/step - loss: 768.8432 - mean_absolute_error: 23.3959 - val_loss: 256.4408 - val_mean_absolute_error: 14.5969
# Epoch 57/100
# 7/7 [==============================] - 0s 5ms/step - loss: 706.6213 - mean_absolute_error: 22.3070 - val_loss: 253.5471 - val_mean_absolute_error: 14.5118
# Epoch 58/100
# 7/7 [==============================] - 0s 5ms/step - loss: 667.9575 - mean_absolute_error: 21.7691 - val_loss: 227.3540 - val_mean_absolute_error: 13.6617
# Epoch 59/100
# 7/7 [==============================] - 0s 6ms/step - loss: 619.9475 - mean_absolute_error: 20.8314 - val_loss: 182.2203 - val_mean_absolute_error: 12.0390
# Epoch 60/100
# 7/7 [==============================] - 0s 5ms/step - loss: 570.1108 - mean_absolute_error: 19.8978 - val_loss: 149.3444 - val_mean_absolute_error: 10.6985
# Epoch 61/100
# 7/7 [==============================] - 0s 5ms/step - loss: 538.0803 - mean_absolute_error: 19.3306 - val_loss: 402.2507 - val_mean_absolute_error: 19.1497
# Epoch 62/100
# 7/7 [==============================] - 0s 5ms/step - loss: 507.6014 - mean_absolute_error: 18.7240 - val_loss: 178.0992 - val_mean_absolute_error: 11.9615
# Epoch 63/100
# 7/7 [==============================] - 0s 5ms/step - loss: 424.2138 - mean_absolute_error: 16.9173 - val_loss: 115.6677 - val_mean_absolute_error: 9.2186
# Epoch 64/100
# 7/7 [==============================] - 0s 6ms/step - loss: 368.0901 - mean_absolute_error: 15.5933 - val_loss: 88.6763 - val_mean_absolute_error: 7.8627
# Epoch 65/100
# 7/7 [==============================] - 0s 5ms/step - loss: 310.3020 - mean_absolute_error: 14.0626 - val_loss: 37.4590 - val_mean_absolute_error: 5.1653
# Epoch 66/100
# 7/7 [==============================] - 0s 6ms/step - loss: 298.6649 - mean_absolute_error: 13.9180 - val_loss: 53.4087 - val_mean_absolute_error: 5.8430
# Epoch 67/100
# 7/7 [==============================] - 0s 5ms/step - loss: 245.4576 - mean_absolute_error: 12.5331 - val_loss: 43.0770 - val_mean_absolute_error: 5.3205
# Epoch 68/100
# 7/7 [==============================] - 0s 5ms/step - loss: 212.8763 - mean_absolute_error: 11.4334 - val_loss: 43.5535 - val_mean_absolute_error: 5.6262
# Epoch 69/100
# 7/7 [==============================] - 0s 5ms/step - loss: 209.2464 - mean_absolute_error: 11.8274 - val_loss: 38.6244 - val_mean_absolute_error: 5.2595
# Epoch 70/100
# 7/7 [==============================] - 0s 5ms/step - loss: 175.3646 - mean_absolute_error: 10.3885 - val_loss: 38.8537 - val_mean_absolute_error: 5.2488
# Epoch 71/100
# 7/7 [==============================] - 0s 6ms/step - loss: 138.2980 - mean_absolute_error: 9.0437 - val_loss: 43.0935 - val_mean_absolute_error: 5.4597
# Epoch 72/100
# 7/7 [==============================] - 0s 6ms/step - loss: 104.1958 - mean_absolute_error: 7.8358 - val_loss: 85.5359 - val_mean_absolute_error: 7.5163
# Epoch 73/100
# 7/7 [==============================] - 0s 6ms/step - loss: 104.2273 - mean_absolute_error: 8.0882 - val_loss: 66.8917 - val_mean_absolute_error: 6.5240
# Epoch 74/100
# 7/7 [==============================] - 0s 6ms/step - loss: 73.1112 - mean_absolute_error: 6.6225 - val_loss: 52.9466 - val_mean_absolute_error: 5.7271
# Epoch 75/100
# 7/7 [==============================] - 0s 6ms/step - loss: 65.7830 - mean_absolute_error: 6.4111 - val_loss: 86.4641 - val_mean_absolute_error: 7.5901
# Epoch 76/100
# 7/7 [==============================] - 0s 6ms/step - loss: 59.0669 - mean_absolute_error: 6.2073 - val_loss: 78.1558 - val_mean_absolute_error: 7.1428
# Epoch 77/100
# 7/7 [==============================] - 0s 6ms/step - loss: 50.3711 - mean_absolute_error: 5.4122 - val_loss: 56.1325 - val_mean_absolute_error: 5.8519
# Epoch 78/100
# 7/7 [==============================] - 0s 6ms/step - loss: 40.7047 - mean_absolute_error: 4.7634 - val_loss: 50.3829 - val_mean_absolute_error: 5.5539
# Epoch 79/100
# 7/7 [==============================] - 0s 5ms/step - loss: 34.5327 - mean_absolute_error: 4.4127 - val_loss: 37.7766 - val_mean_absolute_error: 4.9258
# Epoch 80/100
# 7/7 [==============================] - 0s 5ms/step - loss: 31.4997 - mean_absolute_error: 4.2200 - val_loss: 41.5335 - val_mean_absolute_error: 5.1042
# Epoch 81/100
# 7/7 [==============================] - 0s 5ms/step - loss: 29.7716 - mean_absolute_error: 4.2271 - val_loss: 36.1095 - val_mean_absolute_error: 4.8979
# Epoch 82/100
# 7/7 [==============================] - 0s 6ms/step - loss: 27.7929 - mean_absolute_error: 4.0241 - val_loss: 40.8437 - val_mean_absolute_error: 5.0624
# Epoch 83/100
# 7/7 [==============================] - 0s 5ms/step - loss: 26.8698 - mean_absolute_error: 4.0580 - val_loss: 41.1365 - val_mean_absolute_error: 5.0834
# Epoch 84/100
# 7/7 [==============================] - 0s 6ms/step - loss: 24.1987 - mean_absolute_error: 3.8171 - val_loss: 48.2920 - val_mean_absolute_error: 5.4983
# Epoch 85/100
# 7/7 [==============================] - 0s 5ms/step - loss: 24.3471 - mean_absolute_error: 3.8681 - val_loss: 86.3601 - val_mean_absolute_error: 7.5912
# Epoch 86/100
# 7/7 [==============================] - 0s 5ms/step - loss: 30.1116 - mean_absolute_error: 4.4374 - val_loss: 88.4905 - val_mean_absolute_error: 7.7116
# Epoch 87/100
# 7/7 [==============================] - 0s 6ms/step - loss: 36.3713 - mean_absolute_error: 4.9051 - val_loss: 102.5530 - val_mean_absolute_error: 8.4914
# Epoch 88/100
# 7/7 [==============================] - 0s 5ms/step - loss: 30.3723 - mean_absolute_error: 4.5165 - val_loss: 84.2614 - val_mean_absolute_error: 7.5000
# Epoch 89/100
# 7/7 [==============================] - 0s 6ms/step - loss: 27.9411 - mean_absolute_error: 4.3040 - val_loss: 40.8257 - val_mean_absolute_error: 5.0730
# Epoch 90/100
# 7/7 [==============================] - 0s 6ms/step - loss: 23.0964 - mean_absolute_error: 3.8599 - val_loss: 52.3814 - val_mean_absolute_error: 5.7184
# Epoch 91/100
# 7/7 [==============================] - 0s 6ms/step - loss: 19.5057 - mean_absolute_error: 3.5316 - val_loss: 52.7877 - val_mean_absolute_error: 5.7385
# Epoch 92/100
# 7/7 [==============================] - 0s 6ms/step - loss: 18.9793 - mean_absolute_error: 3.5170 - val_loss: 53.0404 - val_mean_absolute_error: 5.7412
# Epoch 93/100
# 7/7 [==============================] - 0s 6ms/step - loss: 18.3643 - mean_absolute_error: 3.4335 - val_loss: 42.8663 - val_mean_absolute_error: 5.1761
# Epoch 94/100
# 7/7 [==============================] - 0s 6ms/step - loss: 18.3776 - mean_absolute_error: 3.4158 - val_loss: 56.0491 - val_mean_absolute_error: 5.8945
# Epoch 95/100
# 7/7 [==============================] - 0s 6ms/step - loss: 19.2072 - mean_absolute_error: 3.5008 - val_loss: 71.1425 - val_mean_absolute_error: 6.7944
# Epoch 96/100
# 7/7 [==============================] - 0s 5ms/step - loss: 19.0372 - mean_absolute_error: 3.4806 - val_loss: 45.5074 - val_mean_absolute_error: 5.3006
# Epoch 97/100
# 7/7 [==============================] - 0s 5ms/step - loss: 18.5108 - mean_absolute_error: 3.3440 - val_loss: 42.8856 - val_mean_absolute_error: 5.1714
# Epoch 98/100
# 7/7 [==============================] - 0s 5ms/step - loss: 18.6776 - mean_absolute_error: 3.4140 - val_loss: 40.3608 - val_mean_absolute_error: 5.0729
# Epoch 99/100
# 7/7 [==============================] - 0s 5ms/step - loss: 16.7110 - mean_absolute_error: 3.2649 - val_loss: 36.8770 - val_mean_absolute_error: 4.8782
# Epoch 100/100
# 7/7 [==============================] - 0s 6ms/step - loss: 20.9141 - mean_absolute_error: 3.6425 - val_loss: 41.7218 - val_mean_absolute_error: 5.1289

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 13ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 15ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Convert Timestamps to numeric values
dates_train_numeric = np.array([x.value for x in dates_train])
dates_val_numeric = np.array([x.value for x in dates_val])
dates_test_numeric = np.array([x.value for x in dates_test])
recursive_dates_numeric = np.array([x.value for x in recursive_dates])

# Calculate RMSE for each dataset
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
val_rmse = np.sqrt(mean_squared_error(y_val, val_predictions))
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
recursive_rmse = np.sqrt(mean_squared_error(recursive_predictions, recursive_dates_numeric))

print(f"Training RMSE: {train_rmse}")
print(f"Validation RMSE: {val_rmse}")
print(f"Testing RMSE: {test_rmse}")
print(f"Recursive RMSE: {recursive_rmse}")
# Out:
# Training RMSE: 4.069605827331543
# Validation RMSE: 6.459249496459961
# Testing RMSE: 6.8685150146484375
# Recursive RMSE: 1.6448893245914043e+18
